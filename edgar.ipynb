# %% [markdown]
# # Que es la regrecion lineal?

# %% [markdown]
# El termino de regresion se usa cuando se intenta encontrar la relacion entre variables.

# %% [markdown]
# En el siguiente ejemplo el exe x representa la edad de un veiculo  y el eje y representa

# %% [markdown]
# En el aprendizaje automatico y en el modelo estadistico, esta relacion se usa para el resultado de eventos futuros.

# %% [markdown]
# # Que es la regresion lineal?

# %% [markdown]
# La regresion lineal utiliza la relacion entre los puntos de datos para dibujar una linea recta a traves de todosellos

# %% [raw]
# Esta linea se puede usar parapredecir eventos futuros.En aprendizaje automatico, predecir el futuro es muy importante.

# %% [markdown]
# # Como funciona el algoritmo RL?

# %% [raw]
# Python proporcionmetodos para encontrar una relacion entre los puntos de datos y dibujar una linea de regresion lineal. en esta practica vamos a mostrar como usar estos metodos en lugar de pasar directamente a la formula matematica.

# %% [markdown]
# Descripcion del ejemplo a desarrollar

# %% [raw]
# En el siguiente ejemplo, el eje X representa la edad de un veiculo y el eje Y representa la velocidad de un veiculo. Se han registrado 13 autos cuando pasan en tramo carretero. Vamos a analizar si los datos recopilados pueden usarse en regresion lineal.

# %% [markdown]
# ## Ejemplo

# %% [raw]
# Dibujamos un diagrama de dispersion

# %%
import matplotlib.pyplot as plt
x= [5,7,8,7,2,17,2,9,4,11,12,9,6]
y= [99,86,87,88,111,86,103,87,94,78,77,85,86]
plt.scatter(x,y)
plt.show()

# %% [markdown]
# Ejemplo

# %% [markdown]
# Importando libreriasSciPy y dibujamos la linea de regresion lineal

# %%
import matplotlib.pyplot as plt
from scipy import stats

x= [5,7,8,7,2,17,2,9,4,11,12,9,6]
y= [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x,y)

def myfunc(x)
return slope * x + intercep

mymodel = list(map(myfunc,x))

plt.scatter(x,y)
plt.plot(x, mymodel)
plt.show()

# %% [markdown]
# Explicando funcionamiento de algoritmo

# %% [raw]
# Iporta los modulos necesarios

# %%
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# Creamos las matrices que presenten los valores X/Y

# %%
x= [5,7,8,7,2,17,2,9,4,11,12,9,6]
y= [99,86,87,88,111,86,103,87,94,78,77,85,86]

# %% [markdown]
# Ejecutamos el metodo que devuelve algunos valores clave importantes en la regresion lineal

# %%
slop, intercept, r, p, std_errr = stats.linregress(x,y)

# %% [raw]
# Creamos una funcion que use los valores de pendiente e intercepcion para devolver un nuevo valor. Este nuevo valor representa donde en el eje Y se colocara el valor X correspondiente.

# %%
def myfunc(x)
return slop * x + intercept

# %% [raw]
# Ejecutar cada valor de la matriz x a traves de la funcio. Esto da como resultado una nueva matriz con nuevos valorespara el eje Y.

# %%
mymodel = list(mao(myfunc, x))

# %% [raw]
# Dibujamos el diagrama de dispercion original

# %%
plt.scatter(x,y)

# %% [raw]
# Dibujamos la linea de regresion lineal

# %%
plt.plot(x, mymodel)

# %%
[<matplotlib.lines.lines.lines2D at 0x1a2f874d8c8>]

# %% [markdown]
# Mostramos el diagrama

# %%
plot.show()
